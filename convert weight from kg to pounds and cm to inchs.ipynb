# %%
import pandas as pd
import numpy as np
# Step 2: Load the CSV file
df = pd.read_csv('/Users/zahranazemian/Desktop/Python/laptops.csv')
df.head(5)
# Out:
#    Unnamed: 0 Manufacturer  Category     Screen  GPU  OS  CPU_core  \
# 0           0         Acer         4  IPS Panel    2   1         5
# 1           1         Dell         3    Full HD    1   1         3
# 2           2         Dell         3    Full HD    1   1         7
# 3           3         Dell         4  IPS Panel    2   1         5
# 4           4           HP         4    Full HD    2   1         7
#
#    Screen_Size_cm  CPU_frequency  RAM_GB  Storage_GB_SSD  Weight_kg  Price
# 0          35.560            1.6       8             256       1.60    978
# 1          39.624            2.0       4             256       2.20    634
# 2          39.624            2.7       8             256       2.20    946
# 3          33.782            1.6       8             128       1.22   1244
# 4          39.624            1.8       8             256       1.91    837

# %%
# Data standardization: convert screen size from cm to inch
df["Screen_Size_cm"] = df["Screen_Size_cm"]/2.54
df.rename(columns={'Screen_Size_cm':'Screen_Size_inch'}, inplace=True)

# %%
df.head(10)
# Out:
#    Unnamed: 0 Manufacturer  Category     Screen  GPU  OS  CPU_core  \
# 0           0         Acer         4  IPS Panel    2   1         5
# 1           1         Dell         3    Full HD    1   1         3
# 2           2         Dell         3    Full HD    1   1         7
# 3           3         Dell         4  IPS Panel    2   1         5
# 4           4           HP         4    Full HD    2   1         7
# 5           5         Dell         3    Full HD    1   1         5
# 6           6           HP         3    Full HD    3   1         5
# 7           7         Acer         3  IPS Panel    2   1         5
# 8           8         Dell         3    Full HD    1   1         5
# 9           9         Acer         3  IPS Panel    3   1         7
#
#    Screen_Size_inch  CPU_frequency  RAM_GB  Storage_GB_SSD  Weight_kg  Price
# 0              14.0            1.6       8             256       1.60    978
# 1              15.6            2.0       4             256       2.20    634
# 2              15.6            2.7       8             256       2.20    946
# 3              13.3            1.6       8             128       1.22   1244
# 4              15.6            1.8       8             256       1.91    837
# 5              15.6            1.6       8             256       2.20   1016
# 6              15.6            1.6       8             256       2.10   1117
# 7              15.0            1.6       4             256       2.20    866
# 8              15.6            2.5       4             256       2.30    812
# 9              15.0            1.8       8             256       2.20   1068

# %%
df["Screen_Size_inch"].head(10)
# Out:
# 0    14.0
# 1    15.6
# 2    15.6
# 3    13.3
# 4    15.6
# 5    15.6
# 6    15.6
# 7    15.0
# 8    15.6
# 9    15.0
# Name: Screen_Size_inch, dtype: float64

# %%
df["Weight_kg"] = df["Weight_kg"]*2.205
df.rename(columns={'Weight_kg':'Weight_pounds'}, inplace=True)

# %%
# Data standardization: convert weight from kg to pounds
df["Weight_pounds"].head(10)
# Out:
# 0    3.52800
# 1    4.85100
# 2    4.85100
# 3    2.69010
# 4    4.21155
# 5    4.85100
# 6    4.63050
# 7    4.85100
# 8    5.07150
# 9    4.85100
# Name: Weight_pounds, dtype: float64
